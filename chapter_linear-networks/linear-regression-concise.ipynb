# %% [markdown]
# The following additional libraries are needed to run this
# notebook. Note that running on Colab is experimental, please report a Github
# issue if you have any problem.

# %%
# 删除过时的依赖限制
# !sed -i "s/numpy==1.21.5/numpy/" /tmp/pip-req-build-*/setup.py

# 安装可兼容的NumPy版本
# !pip install "numpy>=1.23.5" --upgrade --quiet

# 强制安装d2l-zh（忽略版本限制）
# !pip install git+https://github.com/d2l-ai/d2l-zh@release --no-deps --force-reinstall
# Out:
# sed: can't read /tmp/pip-req-build-*/setup.py: No such file or directory
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 22.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.2 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.2 which is incompatible.
# Collecting git+https://github.com/d2l-ai/d2l-zh@release
#   Cloning https://github.com/d2l-ai/d2l-zh (to revision release) to /tmp/pip-req-build-tcdm8g73
#   Running command git clone --filter=blob:none --quiet https://github.com/d2l-ai/d2l-zh /tmp/pip-req-build-tcdm8g73
#   Running command git checkout -b release --track origin/release
#   Switched to a new branch 'release'
#   Branch 'release' set up to track remote branch 'release' from 'origin'.
#   Resolved https://github.com/d2l-ai/d2l-zh to commit 843d3d41dca48d8df65f4b324dd171d8bfe9c067
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: d2l
#   Building wheel for d2l (setup.py) ... done
#   Created wheel for d2l: filename=d2l-2.0.0-py3-none-any.whl size=110800 sha256=5be3002de5f4ca7a8221ade7f52014026f92db1b01aee5f11729717c892e9c92
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_y8b2gqd/wheels/53/15/45/14b38ed62d9bc53ab3de439d4c2a79f70a00112eeeadcf6c34
# Successfully built d2l
# Installing collected packages: d2l
# Successfully installed d2l-2.0.0

# %% [markdown]
# # 线性回归的简洁实现
# :label:`sec_linear_concise`
#
# 在过去的几年里，出于对深度学习强烈的兴趣，
# 许多公司、学者和业余爱好者开发了各种成熟的开源框架。
# 这些框架可以自动化基于梯度的学习算法中重复性的工作。
# 在 :numref:`sec_linear_scratch`中，我们只运用了：
# （1）通过张量来进行数据存储和线性代数；
# （2）通过自动微分来计算梯度。
# 实际上，由于数据迭代器、损失函数、优化器和神经网络层很常用，
# 现代深度学习库也为我们实现了这些组件。
#
# 本节将介绍如何(**通过使用深度学习框架来简洁地实现**)
#  :numref:`sec_linear_scratch`中的(**线性回归模型**)。
#
# ## 生成数据集
#
# 与 :numref:`sec_linear_scratch`中类似，我们首先[**生成数据集**]。

# %%
import numpy as np
import torch
from torch.utils import data
from d2l import torch as d2l

# %%
true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = d2l.synthetic_data(true_w, true_b, 1000)

# %% [markdown]
# ## 读取数据集
#
# 我们可以[**调用框架中现有的API来读取数据**]。
# 我们将`features`和`labels`作为API的参数传递，并通过数据迭代器指定`batch_size`。
# 此外，布尔值`is_train`表示是否希望数据迭代器对象在每个迭代周期内打乱数据。

# %%
def load_array(data_arrays, batch_size, is_train=True):  #@save
    """构造一个PyTorch数据迭代器"""
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset, batch_size, shuffle=is_train)

# %%
batch_size = 10
data_iter = load_array((features, labels), batch_size)#这个相当于是std::Vector

# %% [markdown]
# 使用`data_iter`的方式与我们在 :numref:`sec_linear_scratch`中使用`data_iter`函数的方式相同。为了验证是否正常工作，让我们读取并打印第一个小批量样本。
# 与 :numref:`sec_linear_scratch`不同，这里我们使用`iter`构造Python迭代器，并使用`next`从迭代器中获取第一项。

# %%
next(iter(data_iter))#这个next其实就是还兼顾删除了。 iter就是构建了迭代器 搞了个vector迭代器 然后next就是迭代器循环。
# Out:
# [tensor([[ 1.5611, -0.3157],
#          [-2.1182,  0.9470],
#          [-2.4695,  0.6085],
#          [ 0.9319, -0.2172],
#          [ 0.6108,  0.1981],
#          [ 1.4968,  0.0868],
#          [ 0.2170,  0.9415],
#          [ 1.0759, -0.0972],
#          [-0.5410,  0.0737],
#          [ 1.8417, -0.5862]]),
#  tensor([[ 8.3985],
#          [-3.2546],
#          [-2.8111],
#          [ 6.8101],
#          [ 4.7533],
#          [ 6.8972],
#          [ 1.4314],
#          [ 6.6697],
#          [ 2.8607],
#          [ 9.8775]])]

# %% [markdown]
# ## 定义模型
#
# 当我们在 :numref:`sec_linear_scratch`中实现线性回归时，
# 我们明确定义了模型参数变量，并编写了计算的代码，这样通过基本的线性代数运算得到输出。
# 但是，如果模型变得更加复杂，且当我们几乎每天都需要实现模型时，自然会想简化这个过程。
# 这种情况类似于为自己的博客从零开始编写网页。
# 做一两次是有益的，但如果每个新博客就需要工程师花一个月的时间重新开始编写网页，那并不高效。
#
# 对于标准深度学习模型，我们可以[**使用框架的预定义好的层**]。这使我们只需关注使用哪些层来构造模型，而不必关注层的实现细节。
# 我们首先定义一个模型变量`net`，它是一个`Sequential`类的实例。
# `Sequential`类将多个层串联在一起。
# 当给定输入数据时，`Sequential`实例将数据传入到第一层，
# 然后将第一层的输出作为第二层的输入，以此类推。
# 在下面的例子中，我们的模型只包含一个层，因此实际上不需要`Sequential`。
# 但是由于以后几乎所有的模型都是多层的，在这里使用`Sequential`会让你熟悉“标准的流水线”。
#
# 回顾 :numref:`fig_single_neuron`中的单层网络架构，
# 这一单层被称为*全连接层*（fully-connected layer），
# 因为它的每一个输入都通过矩阵-向量乘法得到它的每个输出。

# %% [markdown]
# 在PyTorch中，全连接层在`Linear`类中定义。
# 值得注意的是，我们将两个参数传递到`nn.Linear`中。
# 第一个指定输入特征形状，即2，第二个指定输出特征形状，输出特征形状为单个标量，因此为1。

# %%
# nn是神经网络的缩写
from torch import nn

net = nn.Sequential(nn.Linear(2, 1)) #这个2其实就是数据的特征，x1,x2 然后到第一层 w1 w2 所以是w1x2+w2x2 + b 删除 net = nn.Sequential(nn.Linear(2, 1))
#因为输出层只有1 所以就是只有一个节点么，然后这个节点存储着 w1,w2,和b   那么输入就是x1,x2  权重和偏置是“连接线上的参数”，而非节点本身。

# %% [markdown]
# ## (**初始化模型参数**)
#
# 在使用`net`之前，我们需要初始化模型参数。
# 如在线性回归模型中的权重和偏置。
# 深度学习框架通常有预定义的方法来初始化参数。
# 在这里，我们指定每个权重参数应该从均值为0、标准差为0.01的正态分布中随机采样，
# 偏置参数将初始化为零。

# %% [markdown]
# 正如我们在构造`nn.Linear`时指定输入和输出尺寸一样，
# 现在我们能直接访问参数以设定它们的初始值。
# 我们通过`net[0]`选择网络中的第一个图层，
# 然后使用`weight.data`和`bias.data`方法访问参数。
# 我们还可以使用替换方法`normal_`和`fill_`来重写参数值。

# %%
net[0].weight.data.normal_(0, 0.01)
net[0].bias.data.fill_(0)
# Out:
# tensor([0.])

# %% [markdown]
# ## 定义损失函数

# %% [markdown]
# [**计算均方误差使用的是`MSELoss`类，也称为平方$L_2$范数**]。
# 默认情况下，它返回所有样本损失的平均值。

# %%
loss = nn.MSELoss()

# %% [markdown]
# ## 定义优化算法

# %% [markdown]
# 小批量随机梯度下降算法是一种优化神经网络的标准工具，
# PyTorch在`optim`模块中实现了该算法的许多变种。
# 当我们(**实例化一个`SGD`实例**)时，我们要指定优化的参数
# （可通过`net.parameters()`从我们的模型中获得）以及优化算法所需的超参数字典。
# 小批量随机梯度下降只需要设置`lr`值，这里设置为0.03。

# %%
trainer = torch.optim.SGD(net.parameters(), lr=0.03)

# %% [markdown]
# ## 训练
#
# 通过深度学习框架的高级API来实现我们的模型只需要相对较少的代码。
# 我们不必单独分配参数、不必定义我们的损失函数，也不必手动实现小批量随机梯度下降。
# 当我们需要更复杂的模型时，高级API的优势将大大增加。
# 当我们有了所有的基本组件，[**训练过程代码与我们从零开始实现时所做的非常相似**]。
#
# 回顾一下：在每个迭代周期里，我们将完整遍历一次数据集（`train_data`），
# 不停地从中获取一个小批量的输入和相应的标签。
# 对于每一个小批量，我们会进行以下步骤:
#
# * 通过调用`net(X)`生成预测并计算损失`l`（前向传播）。
# * 通过进行反向传播来计算梯度。
# * 通过调用优化器来更新模型参数。
#
# 为了更好的衡量训练效果，我们计算每个迭代周期后的损失，并打印它来监控训练过程。

# %%
num_epochs = 3
for epoch in range(num_epochs):
    for X, y in data_iter:
        l = loss(net(X) ,y)
        trainer.zero_grad()
        l.backward()
          # 输出当前batch的梯度
        print(f"\nBatch Gradients (Epoch {epoch + 1}):")
        print(f"权重梯度:\n{net[0].weight.grad}")
        print(f"偏置梯度:\n{net[0].bias.grad}")

        trainer.step()
    l = loss(net(features), labels)
    print(f'epoch {epoch + 1}, loss {l:f}')
# Out:
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0025, 0.0032]])
# 偏置梯度:
# tensor([-0.0030])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0026, -0.0097]])
# 偏置梯度:
# tensor([-0.0038])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0020,  0.0015]])
# 偏置梯度:
# tensor([-0.0026])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0033, 0.0035]])
# 偏置梯度:
# tensor([-0.0009])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0031, -0.0028]])
# 偏置梯度:
# tensor([-0.0041])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0022, -0.0026]])
# 偏置梯度:
# tensor([-0.0060])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-1.6094e-03, -7.8792e-05]])
# 偏置梯度:
# tensor([0.0113])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0055,  0.0013]])
# 偏置梯度:
# tensor([-0.0100])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0007,  0.0005]])
# 偏置梯度:
# tensor([-0.0069])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0050, -0.0122]])
# 偏置梯度:
# tensor([-0.0020])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0071, -0.0032]])
# 偏置梯度:
# tensor([0.0063])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 4.6271e-06, -7.8602e-03]])
# 偏置梯度:
# tensor([-0.0009])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0039,  0.0003]])
# 偏置梯度:
# tensor([0.0003])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0081,  0.0131]])
# 偏置梯度:
# tensor([-0.0074])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0145, -0.0062]])
# 偏置梯度:
# tensor([-0.0008])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0056, -0.0039]])
# 偏置梯度:
# tensor([-0.0041])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0066,  0.0005]])
# 偏置梯度:
# tensor([0.0061])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0024, -0.0069]])
# 偏置梯度:
# tensor([0.0060])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0005,  0.0068]])
# 偏置梯度:
# tensor([-0.0018])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0083,  0.0003]])
# 偏置梯度:
# tensor([0.0034])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0024,  0.0032]])
# 偏置梯度:
# tensor([-0.0087])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0027, -0.0005]])
# 偏置梯度:
# tensor([-0.0021])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0036, 0.0099]])
# 偏置梯度:
# tensor([0.0125])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0093, 0.0007]])
# 偏置梯度:
# tensor([0.0048])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0124,  0.0022]])
# 偏置梯度:
# tensor([0.0027])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0009,  0.0050]])
# 偏置梯度:
# tensor([0.0037])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0066,  0.0086]])
# 偏置梯度:
# tensor([0.0106])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0041, 0.0022]])
# 偏置梯度:
# tensor([-0.0047])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0030, -0.0030]])
# 偏置梯度:
# tensor([0.0044])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0010,  0.0071]])
# 偏置梯度:
# tensor([-0.0025])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0053, -0.0040]])
# 偏置梯度:
# tensor([0.0008])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0121, -0.0055]])
# 偏置梯度:
# tensor([-0.0083])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[1.7110e-02, 2.8623e-05]])
# 偏置梯度:
# tensor([0.0156])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0004,  0.0019]])
# 偏置梯度:
# tensor([-0.0017])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0014, -0.0007]])
# 偏置梯度:
# tensor([-0.0006])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0011, 0.0021]])
# 偏置梯度:
# tensor([-0.0012])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0036, -0.0022]])
# 偏置梯度:
# tensor([-0.0009])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0037, -0.0060]])
# 偏置梯度:
# tensor([-0.0112])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0077, -0.0019]])
# 偏置梯度:
# tensor([-0.0043])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0021,  0.0006]])
# 偏置梯度:
# tensor([-0.0058])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0011,  0.0114]])
# 偏置梯度:
# tensor([0.0075])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0021, 0.0140]])
# 偏置梯度:
# tensor([0.0070])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0035, 0.0004]])
# 偏置梯度:
# tensor([0.0043])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0084, -0.0038]])
# 偏置梯度:
# tensor([0.0002])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0009, 0.0025]])
# 偏置梯度:
# tensor([0.0005])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0008, 0.0055]])
# 偏置梯度:
# tensor([-0.0005])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0040, -0.0093]])
# 偏置梯度:
# tensor([-0.0075])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0022, -0.0103]])
# 偏置梯度:
# tensor([-0.0035])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0049, -0.0065]])
# 偏置梯度:
# tensor([0.0007])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0028, -0.0116]])
# 偏置梯度:
# tensor([0.0086])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0041, -0.0062]])
# 偏置梯度:
# tensor([-0.0048])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0068, -0.0001]])
# 偏置梯度:
# tensor([-0.0033])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0069, -0.0040]])
# 偏置梯度:
# tensor([0.0058])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0041, -0.0075]])
# 偏置梯度:
# tensor([-9.3640e-05])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0019, 0.0032]])
# 偏置梯度:
# tensor([0.0045])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0025, 0.0119]])
# 偏置梯度:
# tensor([-0.0064])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0063,  0.0054]])
# 偏置梯度:
# tensor([0.0014])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0023, -0.0041]])
# 偏置梯度:
# tensor([-0.0044])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0043, -0.0016]])
# 偏置梯度:
# tensor([-0.0006])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0020, 0.0069]])
# 偏置梯度:
# tensor([0.0094])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0050, -0.0030]])
# 偏置梯度:
# tensor([5.9528e-05])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0003, -0.0026]])
# 偏置梯度:
# tensor([-0.0035])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0024,  0.0093]])
# 偏置梯度:
# tensor([0.0034])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0041, -0.0053]])
# 偏置梯度:
# tensor([-0.0020])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0026, 0.0031]])
# 偏置梯度:
# tensor([0.0069])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0031,  0.0003]])
# 偏置梯度:
# tensor([-0.0024])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0080, -0.0077]])
# 偏置梯度:
# tensor([-0.0042])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0002, -0.0020]])
# 偏置梯度:
# tensor([-0.0106])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0002, -0.0075]])
# 偏置梯度:
# tensor([0.0004])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0128, -0.0107]])
# 偏置梯度:
# tensor([0.0016])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0007, 0.0126]])
# 偏置梯度:
# tensor([-0.0044])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0005, 0.0013]])
# 偏置梯度:
# tensor([-0.0009])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0053, -0.0128]])
# 偏置梯度:
# tensor([0.0072])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0015, -0.0005]])
# 偏置梯度:
# tensor([-0.0014])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0071, -0.0034]])
# 偏置梯度:
# tensor([0.0097])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0062, -0.0028]])
# 偏置梯度:
# tensor([-0.0017])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0024, 0.0033]])
# 偏置梯度:
# tensor([-0.0033])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0077, -0.0033]])
# 偏置梯度:
# tensor([0.0083])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0208, -0.0021]])
# 偏置梯度:
# tensor([-0.0009])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0068, 0.0114]])
# 偏置梯度:
# tensor([0.0041])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0004,  0.0005]])
# 偏置梯度:
# tensor([-0.0117])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0043, -0.0154]])
# 偏置梯度:
# tensor([-0.0037])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0083, 0.0116]])
# 偏置梯度:
# tensor([0.0033])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0048, 0.0034]])
# 偏置梯度:
# tensor([-0.0065])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0144,  0.0166]])
# 偏置梯度:
# tensor([0.0097])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0036, -0.0149]])
# 偏置梯度:
# tensor([0.0023])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0054, 0.0064]])
# 偏置梯度:
# tensor([-0.0076])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0013, 0.0026]])
# 偏置梯度:
# tensor([0.0028])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0047,  0.0063]])
# 偏置梯度:
# tensor([-0.0082])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0152, -0.0009]])
# 偏置梯度:
# tensor([0.0107])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0003, -0.0025]])
# 偏置梯度:
# tensor([0.0134])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0118,  0.0015]])
# 偏置梯度:
# tensor([-0.0024])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0054,  0.0022]])
# 偏置梯度:
# tensor([0.0028])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0048, 0.0058]])
# 偏置梯度:
# tensor([-0.0004])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0095, 0.0025]])
# 偏置梯度:
# tensor([-0.0069])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[ 0.0005, -0.0009]])
# 偏置梯度:
# tensor([0.0037])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[0.0070, 0.0111]])
# 偏置梯度:
# tensor([0.0039])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0001,  0.0027]])
# 偏置梯度:
# tensor([0.0008])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0022, -0.0081]])
# 偏置梯度:
# tensor([0.0083])
#
# Batch Gradients (Epoch 1):
# 权重梯度:
# tensor([[-0.0048, -0.0014]])
# 偏置梯度:
# tensor([0.0138])
# epoch 1, loss 0.000098
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0045, -0.0018]])
# 偏置梯度:
# tensor([-0.0058])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0059,  0.0024]])
# 偏置梯度:
# tensor([-0.0026])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0062,  0.0059]])
# 偏置梯度:
# tensor([0.0045])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0062, -0.0024]])
# 偏置梯度:
# tensor([-0.0119])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0027,  0.0062]])
# 偏置梯度:
# tensor([0.0058])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0022, -0.0052]])
# 偏置梯度:
# tensor([0.0006])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-5.3508e-03, -6.4149e-05]])
# 偏置梯度:
# tensor([0.0101])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0080, -0.0090]])
# 偏置梯度:
# tensor([0.0013])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0032, -0.0066]])
# 偏置梯度:
# tensor([-0.0018])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0039, -0.0033]])
# 偏置梯度:
# tensor([0.0109])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0003, 0.0037]])
# 偏置梯度:
# tensor([-0.0065])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0018, -0.0051]])
# 偏置梯度:
# tensor([-0.0055])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0021, -0.0042]])
# 偏置梯度:
# tensor([-0.0079])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0083, 0.0095]])
# 偏置梯度:
# tensor([-0.0106])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0001,  0.0097]])
# 偏置梯度:
# tensor([-0.0043])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0026, -0.0013]])
# 偏置梯度:
# tensor([0.0060])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0020, 0.0090]])
# 偏置梯度:
# tensor([-0.0076])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0037, 0.0072]])
# 偏置梯度:
# tensor([-0.0103])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0048, -0.0029]])
# 偏置梯度:
# tensor([-0.0016])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0156,  0.0010]])
# 偏置梯度:
# tensor([0.0157])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0019, -0.0069]])
# 偏置梯度:
# tensor([-0.0086])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0097, -0.0116]])
# 偏置梯度:
# tensor([-0.0063])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0032,  0.0103]])
# 偏置梯度:
# tensor([-0.0009])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0083, 0.0011]])
# 偏置梯度:
# tensor([-0.0114])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0069,  0.0098]])
# 偏置梯度:
# tensor([-0.0007])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0037, -0.0056]])
# 偏置梯度:
# tensor([0.0040])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0115, -0.0030]])
# 偏置梯度:
# tensor([-0.0108])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0018, -0.0053]])
# 偏置梯度:
# tensor([0.0159])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0050, -0.0042]])
# 偏置梯度:
# tensor([0.0013])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0014, 0.0056]])
# 偏置梯度:
# tensor([-0.0003])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0044, 0.0032]])
# 偏置梯度:
# tensor([0.0005])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0008,  0.0010]])
# 偏置梯度:
# tensor([-0.0118])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0013, -0.0054]])
# 偏置梯度:
# tensor([0.0062])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0126, -0.0020]])
# 偏置梯度:
# tensor([-0.0044])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0029, -0.0111]])
# 偏置梯度:
# tensor([-0.0013])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0067,  0.0036]])
# 偏置梯度:
# tensor([-0.0034])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0072, -0.0014]])
# 偏置梯度:
# tensor([0.0063])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0051,  0.0096]])
# 偏置梯度:
# tensor([0.0043])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0025, 0.0065]])
# 偏置梯度:
# tensor([0.0047])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0049, -0.0064]])
# 偏置梯度:
# tensor([-0.0047])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0086, -0.0088]])
# 偏置梯度:
# tensor([0.0008])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0039, 0.0051]])
# 偏置梯度:
# tensor([0.0011])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0049, 0.0002]])
# 偏置梯度:
# tensor([0.0023])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0044, 0.0020]])
# 偏置梯度:
# tensor([-0.0004])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[5.4759e-03, 6.7047e-05]])
# 偏置梯度:
# tensor([0.0007])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0064, -0.0023]])
# 偏置梯度:
# tensor([0.0024])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0030, -0.0021]])
# 偏置梯度:
# tensor([-0.0070])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0017, -0.0108]])
# 偏置梯度:
# tensor([0.0045])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0018,  0.0135]])
# 偏置梯度:
# tensor([0.0018])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0062, 0.0058]])
# 偏置梯度:
# tensor([-0.0129])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0068,  0.0144]])
# 偏置梯度:
# tensor([-0.0130])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0028, -0.0077]])
# 偏置梯度:
# tensor([-0.0042])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0038, -0.0104]])
# 偏置梯度:
# tensor([0.0158])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0159,  0.0015]])
# 偏置梯度:
# tensor([0.0097])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0046, 0.0002]])
# 偏置梯度:
# tensor([0.0022])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0091, -0.0049]])
# 偏置梯度:
# tensor([0.0085])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0103, -0.0030]])
# 偏置梯度:
# tensor([0.0058])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0003,  0.0062]])
# 偏置梯度:
# tensor([-0.0014])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0131, -0.0095]])
# 偏置梯度:
# tensor([0.0017])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0060,  0.0026]])
# 偏置梯度:
# tensor([0.0064])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0100, 0.0028]])
# 偏置梯度:
# tensor([0.0086])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0004,  0.0043]])
# 偏置梯度:
# tensor([-0.0024])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0001, -0.0096]])
# 偏置梯度:
# tensor([-0.0043])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0097, -0.0032]])
# 偏置梯度:
# tensor([0.0069])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0005, -0.0046]])
# 偏置梯度:
# tensor([-0.0050])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0119, -0.0032]])
# 偏置梯度:
# tensor([-0.0003])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0059,  0.0073]])
# 偏置梯度:
# tensor([-0.0032])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0015, 0.0008]])
# 偏置梯度:
# tensor([0.0038])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0042, 0.0068]])
# 偏置梯度:
# tensor([-0.0043])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0014,  0.0049]])
# 偏置梯度:
# tensor([-0.0002])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0017, -0.0061]])
# 偏置梯度:
# tensor([-0.0045])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0047,  0.0175]])
# 偏置梯度:
# tensor([-1.1322e-05])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-2.7866e-06, -7.2381e-03]])
# 偏置梯度:
# tensor([-0.0024])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0109,  0.0095]])
# 偏置梯度:
# tensor([0.0017])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0050, -0.0011]])
# 偏置梯度:
# tensor([-0.0099])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0050, -0.0045]])
# 偏置梯度:
# tensor([-0.0086])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 1.0064e-02, -9.8330e-05]])
# 偏置梯度:
# tensor([-0.0083])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0019, -0.0093]])
# 偏置梯度:
# tensor([-0.0038])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0014, -0.0057]])
# 偏置梯度:
# tensor([0.0043])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0147, 0.0047]])
# 偏置梯度:
# tensor([-0.0046])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0055, 0.0028]])
# 偏置梯度:
# tensor([-0.0032])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0041,  0.0028]])
# 偏置梯度:
# tensor([-0.0011])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0028,  0.0016]])
# 偏置梯度:
# tensor([0.0123])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0134, -0.0027]])
# 偏置梯度:
# tensor([0.0073])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0015, -0.0049]])
# 偏置梯度:
# tensor([-0.0102])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0029, -0.0102]])
# 偏置梯度:
# tensor([0.0017])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0010, -0.0087]])
# 偏置梯度:
# tensor([0.0067])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0042, -0.0058]])
# 偏置梯度:
# tensor([0.0114])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0022,  0.0086]])
# 偏置梯度:
# tensor([-0.0058])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0105, -0.0118]])
# 偏置梯度:
# tensor([0.0056])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0029, 0.0027]])
# 偏置梯度:
# tensor([-0.0018])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0023, -0.0123]])
# 偏置梯度:
# tensor([-0.0053])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0054, 0.0052]])
# 偏置梯度:
# tensor([-0.0006])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0100, -0.0077]])
# 偏置梯度:
# tensor([-0.0022])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0010, 0.0084]])
# 偏置梯度:
# tensor([-0.0004])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[-0.0035,  0.0127]])
# 偏置梯度:
# tensor([-0.0066])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0060, -0.0016]])
# 偏置梯度:
# tensor([0.0080])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[0.0028, 0.0016]])
# 偏置梯度:
# tensor([0.0019])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0053, -0.0053]])
# 偏置梯度:
# tensor([0.0148])
#
# Batch Gradients (Epoch 2):
# 权重梯度:
# tensor([[ 0.0052, -0.0050]])
# 偏置梯度:
# tensor([-0.0035])
# epoch 2, loss 0.000098
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0028, 0.0043]])
# 偏置梯度:
# tensor([-0.0016])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0021, 0.0218]])
# 偏置梯度:
# tensor([0.0095])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0031,  0.0013]])
# 偏置梯度:
# tensor([0.0093])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0088, -0.0083]])
# 偏置梯度:
# tensor([0.0005])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0056, -0.0097]])
# 偏置梯度:
# tensor([0.0059])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0064, -0.0018]])
# 偏置梯度:
# tensor([-0.0011])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0055,  0.0008]])
# 偏置梯度:
# tensor([0.0083])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0013,  0.0043]])
# 偏置梯度:
# tensor([-0.0066])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0031, -0.0059]])
# 偏置梯度:
# tensor([-0.0018])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0049, -0.0047]])
# 偏置梯度:
# tensor([-0.0030])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0019,  0.0037]])
# 偏置梯度:
# tensor([-0.0075])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0015,  0.0086]])
# 偏置梯度:
# tensor([-0.0084])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0007,  0.0019]])
# 偏置梯度:
# tensor([-0.0040])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0033,  0.0126]])
# 偏置梯度:
# tensor([-0.0014])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0053, -0.0162]])
# 偏置梯度:
# tensor([-0.0008])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0021, -0.0005]])
# 偏置梯度:
# tensor([-0.0044])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0021, -0.0115]])
# 偏置梯度:
# tensor([-0.0003])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0029,  0.0209]])
# 偏置梯度:
# tensor([-0.0002])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0126, 0.0045]])
# 偏置梯度:
# tensor([-0.0021])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0044, -0.0091]])
# 偏置梯度:
# tensor([0.0063])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0030,  0.0051]])
# 偏置梯度:
# tensor([-0.0067])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0022, 0.0071]])
# 偏置梯度:
# tensor([-0.0094])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0015,  0.0060]])
# 偏置梯度:
# tensor([-0.0014])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0098, -0.0049]])
# 偏置梯度:
# tensor([0.0069])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0023, -0.0024]])
# 偏置梯度:
# tensor([-0.0043])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0003,  0.0046]])
# 偏置梯度:
# tensor([0.0037])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0006,  0.0023]])
# 偏置梯度:
# tensor([0.0072])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0066, -0.0144]])
# 偏置梯度:
# tensor([-0.0143])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0063, -0.0018]])
# 偏置梯度:
# tensor([0.0033])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0039, -0.0023]])
# 偏置梯度:
# tensor([0.0182])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0099, 0.0072]])
# 偏置梯度:
# tensor([-0.0101])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0016, -0.0010]])
# 偏置梯度:
# tensor([-0.0058])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0013, -0.0100]])
# 偏置梯度:
# tensor([-0.0029])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0037, 0.0119]])
# 偏置梯度:
# tensor([0.0095])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0046, 0.0119]])
# 偏置梯度:
# tensor([0.0031])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0015,  0.0022]])
# 偏置梯度:
# tensor([-0.0006])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0005, 0.0001]])
# 偏置梯度:
# tensor([-0.0017])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0109,  0.0011]])
# 偏置梯度:
# tensor([0.0063])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0034, 0.0042]])
# 偏置梯度:
# tensor([-0.0006])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0093, -0.0014]])
# 偏置梯度:
# tensor([-0.0065])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0034, 0.0009]])
# 偏置梯度:
# tensor([0.0074])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0023, -0.0053]])
# 偏置梯度:
# tensor([0.0028])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0033,  0.0116]])
# 偏置梯度:
# tensor([0.0134])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0045, -0.0074]])
# 偏置梯度:
# tensor([-0.0051])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0028, 0.0041]])
# 偏置梯度:
# tensor([-0.0047])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0060, -0.0075]])
# 偏置梯度:
# tensor([-0.0079])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0132, -0.0088]])
# 偏置梯度:
# tensor([0.0006])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0012, -0.0039]])
# 偏置梯度:
# tensor([-0.0048])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0054, 0.0006]])
# 偏置梯度:
# tensor([0.0079])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0055, -0.0069]])
# 偏置梯度:
# tensor([0.0060])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0002, -0.0068]])
# 偏置梯度:
# tensor([0.0041])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0025,  0.0123]])
# 偏置梯度:
# tensor([0.0026])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0011, -0.0069]])
# 偏置梯度:
# tensor([-0.0058])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0207, 0.0014]])
# 偏置梯度:
# tensor([-9.8515e-05])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0111, -0.0028]])
# 偏置梯度:
# tensor([-0.0033])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0033,  0.0005]])
# 偏置梯度:
# tensor([0.0063])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0021, -0.0011]])
# 偏置梯度:
# tensor([-0.0060])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0034,  0.0058]])
# 偏置梯度:
# tensor([-0.0073])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0034, -0.0082]])
# 偏置梯度:
# tensor([0.0086])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0088,  0.0007]])
# 偏置梯度:
# tensor([0.0060])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0068, -0.0111]])
# 偏置梯度:
# tensor([0.0057])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0027, 0.0005]])
# 偏置梯度:
# tensor([-0.0002])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0082, 0.0005]])
# 偏置梯度:
# tensor([0.0068])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0024, 0.0050]])
# 偏置梯度:
# tensor([-0.0106])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0072, -0.0033]])
# 偏置梯度:
# tensor([0.0051])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0080, 0.0105]])
# 偏置梯度:
# tensor([0.0036])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0068, -0.0042]])
# 偏置梯度:
# tensor([-0.0117])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0020, -0.0049]])
# 偏置梯度:
# tensor([-0.0027])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0026,  0.0037]])
# 偏置梯度:
# tensor([0.0014])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0040, -0.0042]])
# 偏置梯度:
# tensor([-0.0012])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0046, -0.0009]])
# 偏置梯度:
# tensor([-0.0065])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0091,  0.0026]])
# 偏置梯度:
# tensor([-0.0041])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0170, 0.0122]])
# 偏置梯度:
# tensor([0.0083])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0076, -0.0006]])
# 偏置梯度:
# tensor([-0.0087])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0117,  0.0009]])
# 偏置梯度:
# tensor([0.0035])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0047, -0.0069]])
# 偏置梯度:
# tensor([0.0001])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0024,  0.0015]])
# 偏置梯度:
# tensor([0.0023])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0015, 0.0029]])
# 偏置梯度:
# tensor([-0.0035])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0050, 0.0088]])
# 偏置梯度:
# tensor([-0.0027])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0012,  0.0044]])
# 偏置梯度:
# tensor([0.0068])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 3.5115e-05, -1.7615e-04]])
# 偏置梯度:
# tensor([-0.0047])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0021,  0.0024]])
# 偏置梯度:
# tensor([0.0004])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0018, -0.0041]])
# 偏置梯度:
# tensor([-0.0081])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0111, -0.0028]])
# 偏置梯度:
# tensor([-0.0024])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0017, -0.0008]])
# 偏置梯度:
# tensor([0.0045])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0079, -0.0089]])
# 偏置梯度:
# tensor([0.0050])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0044, 0.0004]])
# 偏置梯度:
# tensor([-0.0033])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0118,  0.0023]])
# 偏置梯度:
# tensor([0.0004])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0046, 0.0009]])
# 偏置梯度:
# tensor([0.0004])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0033,  0.0057]])
# 偏置梯度:
# tensor([-0.0065])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0030, 0.0004]])
# 偏置梯度:
# tensor([-0.0028])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0003, -0.0054]])
# 偏置梯度:
# tensor([-0.0013])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0022, -0.0041]])
# 偏置梯度:
# tensor([-0.0016])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0184,  0.0025]])
# 偏置梯度:
# tensor([-0.0081])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0074, 0.0014]])
# 偏置梯度:
# tensor([-0.0080])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0007, -0.0032]])
# 偏置梯度:
# tensor([-0.0003])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[ 0.0099, -0.0014]])
# 偏置梯度:
# tensor([0.0043])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0044, -0.0015]])
# 偏置梯度:
# tensor([-0.0079])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[-0.0143, -0.0105]])
# 偏置梯度:
# tensor([-0.0039])
#
# Batch Gradients (Epoch 3):
# 权重梯度:
# tensor([[0.0009, 0.0050]])
# 偏置梯度:
# tensor([-0.0026])
# epoch 3, loss 0.000098

# %% [markdown]
# 下面我们[**比较生成数据集的真实参数和通过有限数据训练获得的模型参数**]。
# 要访问参数，我们首先从`net`访问所需的层，然后读取该层的权重和偏置。
# 正如在从零开始实现中一样，我们估计得到的参数与生成数据的真实参数非常接近。

# %%
w = net[0].weight.data
print('w的估计误差：', true_w - w.reshape(true_w.shape))
b = net[0].bias.data
print('b的估计误差：', true_b - b)
# Out:
# w的估计误差： tensor([-0.0003,  0.0009])
# b的估计误差： tensor([0.0003])

# %% [markdown]
# ## 小结

# %% [markdown]
# * 我们可以使用PyTorch的高级API更简洁地实现模型。
# * 在PyTorch中，`data`模块提供了数据处理工具，`nn`模块定义了大量的神经网络层和常见损失函数。
# * 我们可以通过`_`结尾的方法将参数替换，从而初始化参数。

# %% [markdown]
# ## 练习
#
# 1. 如果将小批量的总损失替换为小批量损失的平均值，需要如何更改学习率？
# 1. 查看深度学习框架文档，它们提供了哪些损失函数和初始化方法？用Huber损失代替原损失，即
#     $$l(y,y') = \begin{cases}|y-y'| -\frac{\sigma}{2} & \text{ if } |y-y'| > \sigma \\ \frac{1}{2 \sigma} (y-y')^2 & \text{ 其它情况}\end{cases}$$
# 1. 如何访问线性回归的梯度？

# %%
 lr=base_lr / batch_size

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/1781)
